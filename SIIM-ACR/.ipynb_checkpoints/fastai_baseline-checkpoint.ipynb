# %%
from fastai.vision import *

# %%
PATH = Path("/home/ubuntu/data/kaggle/old/all_data/input/train/")

# %%
PATH.ls()
# Out:
# [PosixPath('/home/ubuntu/data/kaggle/old/all_data/input/train/dicom'),
#  PosixPath('/home/ubuntu/data/kaggle/old/all_data/input/train/mask'),
#  PosixPath('/home/ubuntu/data/kaggle/old/all_data/input/train/mask-flip'),
#  PosixPath('/home/ubuntu/data/kaggle/old/all_data/input/train/.DS_Store'),
#  PosixPath('/home/ubuntu/data/kaggle/old/all_data/input/train/DCIM')]

# %%
labels_path = PATH/"mask-flip"
images_path = PATH/"dicom"

# %%
im_names = get_image_files(images_path)
label_names = get_image_files(labels_path)

# %%
img = open_image(im_names[1])
img.show()

# %%
get_y_fn = lambda x: labels_path/f'{x.name}'

# %%
mask = open_mask(get_y_fn(im_names[9703]))
